# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\wassf\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wassf\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\wassf\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\wassf\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\wassf\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\wassf\anaconda3\lib\site-packages (1.21.5)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\wassf\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\wassf\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\wassf\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wassf\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\wassf\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wassf\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\wassf\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\wassf\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\wassf\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\wassf\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import csv

csvfile = pd.read_csv("PIB_reg_dep.csv", sep=";",encoding='ANSI',usecols = ['Departements','PIB_dep_euros'])
csvfile.head
# Out:
# <bound method NDFrame.head of          Departements  PIB_dep_euros
# 0               Paris          47695
# 1      Hauts-de-Seine          45141
# 2            Yvelines          40347
# 3        Haute-Savoie          36766
# 4                 Ain          31232
# ..                ...            ...
# 89               Aude          21669
# 90  Seine-Saint-Denis          21565
# 91             Ariege          21250
# 92             Creuse          20301
# 93             Monaco          82500
#
# [94 rows x 2 columns]>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import csv

csvfile = pd.read_csv("test1.csv", sep=";",encoding='ANSI',usecols = ['Departements','PIB_dep_euros','Numero_Departement'])
csvfile.head(10)

plt.plot(csvfile['Departements'], csvfile['PIB_dep_euros'])
plt.title('PIB en milliers euros par habitants')
plt.xlabel('Nom departements')
plt.ylabel('PIB departements')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
from dateutil import parser
import json 
import seaborn as sns
from pymongo import MongoClient 


CONNECTION_STRING="mongodb://127.0.0.1:27017/?directConnection=true&serverSelectionTimeoutMS=2000&appName=mongosh+1.6.1"
client = MongoClient(CONNECTION_STRING)


print("Connexion établie")

mydb = client["Projet"]
mycol = mydb["PIB_Dep_Reg"]


for x in mycol.find({},{ "_id": 0, "Rang": 1, "Departements": 1, "PIB_dep_euros": 1, "Numero_Departement": 1, "Region": 1, "PIB_Region (en milliard d'euro)": 1 }):
   
    plt.bar(x['Departements'], x['PIB_dep_euros'])
    
plt.rcParams['figure.figsize']=(20, 10)    
plt.title('PIB en milliers euros par habitants')
plt.xlabel('Nom departements')
plt.ylabel('PIB departements')
plt.xticks(rotation = 90)
plt.show()
# Out:
# Connexion établie

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
from dateutil import parser
import json 
import seaborn as sns
from pymongo import MongoClient 


CONNECTION_STRING="mongodb://127.0.0.1:27017/?directConnection=true&serverSelectionTimeoutMS=2000&appName=mongosh+1.6.1"
client = MongoClient(CONNECTION_STRING)


print("Connexion établie")

mydb = client["Projet"]
mycol = mydb["PIB_Dep_Reg"]


for x in mycol.find({},{ "_id": 0, "Rang": 1, "Departements": 1, "PIB_dep_euros": 1, "Numero_Departement": 1, "Region": 1, "PIB_Region (en milliard euro)": 1 }):
   
    
    plt.bar(x["Region"], x['PIB_Region (en milliard euro)'])

    
    
plt.rcParams['figure.figsize']=(20, 10)    
plt.title('PIB des Régions')
plt.xlabel('Régions')
plt.ylabel('PIB')
plt.xticks(rotation = 45)
plt.show()
# Out:
# Connexion établie

# %% [markdown]
# ##### import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# import csv
# from dateutil import parser
# import json
# import seaborn as sns
# from pymongo import MongoClient
#
#
# CONNECTION_STRING="mongodb://127.0.0.1:27017/?directConnection=true&serverSelectionTimeoutMS=2000&appName=mongosh+1.6.1"
# client = MongoClient(CONNECTION_STRING)
#
#
# print("Connexion établie")
#
# mydb = client["Projet"]
# mycol = mydb["Voitures_PIB"]
#
#
# for x in mycol.aggregate( [{ "$group":{ "_id": "$Departements","average":{"$avg":"$Listes_Voitures[2]"}} } ] ):
#
#     print(x)
#     plt.bar(x['_id'], x['average'])
#
#
#
# plt.rcParams['figure.figsize']=(20, 10)
# plt.title('Marque vendue par Region')
# plt.xlabel('Nom région')
# plt.ylabel('Prix')
# plt.xticks(rotation = 90)
# plt.show()
